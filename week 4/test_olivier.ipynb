# %%
import pandas as pd
df=pd.read_excel('hotelBookings.xlsx')

# %%
#all items in the hotel column are resort hotel and all items in the company column are NaN, therefore these will be removed
removed_columns=['hotel','company']
df=df[[item for item in df.columns if item not in removed_columns]]

# %%
import pandas as pd
df = pd.read_excel('dataProject4.xlsx',header=4,sheet_name='20000-211000')
df=df.iloc[:,:7].join(df.iloc[:,7:].rename(columns={df.iloc[:,7:].columns[i]:f'volume {2018+i}' for i in range(len(df.iloc[:,7:].columns))}))

# %%
print(f'are there any NaN cells in non-result rows? {(df[df.isna().any(axis=1)]['Customer Classification (CRM)']!='Result').any()}')
# Out:
# are there any NaN cells in non-result rows? False

# %%
df['Horeca menu webshop'].isna()
# Out:
# RangeIndex(start=0, stop=82334, step=1)

# %%
df
# Out:
#        2f. Customer number Postal Code Customer Classification (CRM)  \
# 0                   200001     5735 SC                       Voetbal
# 1                   200001     5735 SC                       Voetbal
# 2                   200001     5735 SC                       Voetbal
# 3                   200001     5735 SC                       Voetbal
# 4                   200001     5735 SC                       Voetbal
# ...                    ...         ...                           ...
# 82329               211000     6815 AH                  Jeugdherberg
# 82330               211000     6815 AH                  Jeugdherberg
# 82331               211000     6815 AH                  Jeugdherberg
# 82332               211000     6815 AH                  Jeugdherberg
# 82333               211000     6815 AH                        Result
#
#         Horeca menu webshop Prd. name Webshop 1c. Brand name  Contents  \
# 0      Bier - Alcoholvrij/a               0.0           PALM      0.25
# 1      Bier - Alcoholvrij/a           0.0 IPA        BAVARIA      0.30
# 2      Bier - Alcoholvrij/a      0.0 Original        BAVARIA      0.30
# 3      Bier - Alcoholvrij/a        0.0 Radler        BAVARIA      0.30
# 4      Bier - Alcoholvrij/a           0.0 Wit        BAVARIA      0.30
# ...                     ...               ...            ...       ...
# 82329            Wijn - Wit    Winzerschoppen      KONIGSHOF      1.00
# 82330     Zuivel - Chocomel      Not assigned       CHOCOMEL      0.20
# 82331  Zuivel - Fruitzuivel        Rood Fruit         FRISTI      0.20
# 82332          Not assigned      Not assigned        BAVARIA      0.30
# 82333                   NaN               NaN            NaN       NaN
#
#        volume 2018  volume 2019  volume 2020  volume 2021  volume 2022
# 0            0.000        0.000        0.060        0.000       0.0000
# 1            0.000        0.072        0.144        0.000       0.0000
# 2            0.000        0.000        0.000        0.072       0.4320
# 3            0.000        0.792        0.360        0.180       0.4320
# 4            0.000        0.000        0.000        0.000       0.0864
# ...            ...          ...          ...          ...          ...
# 82329        0.000        0.540        0.120        0.060       0.4320
# 82330        0.960        0.768        0.528        0.720       0.5184
# 82331        0.336        0.288        0.240        0.240       0.7488
# 82332        0.000        0.000        0.072        0.000       0.0864
# 82333      121.783      125.645       42.527       41.212      69.3480
#
# [82334 rows x 12 columns]
