# %%
import pandas as pd
df=pd.read_excel('hotelBookings.xlsx')

# %%
#all items in the hotel column are resort hotel and all items in the company column are NaN, therefore these will be removed
removed_columns=['hotel','company']
df=df[[item for item in df.columns if item not in removed_columns]]

# %%
import pandas as pd
df = pd.read_excel('dataProject4.xlsx',header=4,sheet_name='20000-211000')
df=df.iloc[:,:7].join(df.iloc[:,7:].rename(columns={df.iloc[:,7:].columns[i]:f'volume {2018+i}' for i in range(len(df.iloc[:,7:].columns))}))
df=df.rename(columns={df.columns[i]:df.columns[i].split('. ')[-1] for i in range(len(df.columns))})

# %%
print(f'are there any NaN cells in non-result rows? {(df[df.isna().any(axis=1)]['Customer Classification (CRM)']!='Result').any()}')
# Out:
# are there any NaN cells in non-result rows? False

# %%
len(df[(df.loc[:,['Brand name']] == 'Not assigned').any(axis=1)]['2f. Customer number'].unique()),len(df['2f. Customer number'].unique())
# Out:
# (1, 896)

# %%
a=df['Brand name'] == 'Not assigned'
print(len(df[a]), len(df))
d
# Out:
# 1 82334
#        Customer number Postal Code Customer Classification (CRM)  \
# 71067           209921     5051 DS                 Drankenhandel
#
#       Horeca menu webshop    name Webshop    Brand name  Contents  \
# 71067        Bier - Blond  Geef en Geniet  Not assigned      19.5
#
#        volume 2018  volume 2019  volume 2020  volume 2021  volume 2022
# 71067          0.0         0.78          0.0          0.0          0.0

# %%
df[(df=='Not assigned').sum(axis=1)>=2]
# Out:
#        Customer number Postal Code Customer Classification (CRM)  \
# 429             200046     7607 AE                         Hotel
# 487             200053     1185 XP                 Overige Sport
# 603             200062     6075 CD                          Golf
# 787             200073     6702 PB                     Studenten
# 1129            200078     3524 BN           Zaal / Partycentrum
# ...                ...         ...                           ...
# 81339           210929     4463 AJ                 Overige Sport
# 81532           210955     5706 CT                          Café
# 81748           210986     3632 AJ                        Hockey
# 82218           210999     7312 TS                  Jeugdherberg
# 82332           211000     6815 AH                  Jeugdherberg
#
#       Horeca menu webshop  name Webshop Brand name  Contents  volume 2018  \
# 429          Not assigned  Not assigned    BAVARIA       0.3          0.0
# ...

# %%
import pandas as pd
df=pd.read_excel('detailedRetail.xlsx')
df_report=pd.DataFrame({
})

# %%
for loop, name in zip(range(len(df['Sales Manager'].unique())), df['Sales Manager'].unique()):
    for i in range(len(df['Category'].unique())):
        df_report.loc[i+(len(df.Category.unique())+1)*loop,'Category']=f'{name}: {df['Category'].unique()[i]}'
        for month in df['Month'].unique():
            df_report.loc[i+(len(df.Category.unique())+1)*loop,month]=df[(df['Category']==df['Category'].unique()[i]) * (df['Month']==month)*(df['Sales Manager']==name)]['Sales'].sum()
        df_report.loc[i+(len(df.Category.unique())+1)*loop,'Total revenue months']=df[(df['Category']==df['Category'].unique()[i])*(df['Sales Manager']==name)]['Sales'].sum()
    df_report.loc[(len(df.Category.unique())+1)*(loop+1)-1,'Category']=f'{name} Total' 
    for colm in [item for item in df_report.columns if item != 'Category']:
        df_report.loc[(len(df.Category.unique())+1)*(loop+1)-1,colm]=sum(df_report.loc[(len(df.Category.unique())+1)*loop:(len(df.Category.unique())+1)*(loop+1)-2,colm])

# %%
loop=len(df['Sales Manager'].unique())
for i in range(len(df['Category'].unique())):
    df_report.loc[i+(len(df.Category.unique())+1)*loop,'Category']=f'total:\n {df['Category'].unique()[i]}'
    for month in df['Month'].unique():
        df_report.loc[i+(len(df.Category.unique())+1)*loop,month]=df[(df['Category']==df['Category'].unique()[i]) * (df['Month']==month)]['Sales'].sum()
    df_report.loc[i+(len(df.Category.unique())+1)*loop,'Total revenue months']=df[(df['Category']==df['Category'].unique()[i])]['Sales'].sum()
df_report.loc[(len(df.Category.unique())+1)*(loop+1)-1,'Category']='Final Total'
for colm in [item for item in df_report.columns if item != 'Category']:
    df_report.loc[(len(df.Category.unique())+1)*(loop+1)-1,colm]=sum(df_report.loc[(len(df.Category.unique())+1)*loop:(len(df.Category.unique())+1)*(loop+1)-2,colm])

# %%
for loop in range(len(df['Sales Manager'].unique())+1):
    df_report=df_report.style.map(df_style, subset=(len(df.Category.unique())+1)*(loop+1)-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[229], line 2
#       1 for loop in range(len(df['Sales Manager'].unique())+1):
# ----> 2     df_report=df_report.style.map(df_style, subset=(len(df.Category.unique())+1)*(loop+1)-1)
#
# AttributeError: 'Styler' object has no attribute 'style'

# %%
len(df_report.index)
# Out:
# 36

# %%
(df.sort_values(by=['Sales'],ascending=False)['Sales Manager']=='Donald Ducker') * (df.sort_values(by=['Sales'],ascending=False)['Month']=='May')
# Out:
# 0      False
# 36     False
# 144     True
# 2      False
# 38     False
#        ...
# 131    False
# 132    False
# 94     False
# 166    False
# 130    False
# Length: 180, dtype: bool

# %%
a=pd.DataFrame({
    'a':[1,2,3,4,5],
    'b':[6,7,8,9,10]
})

# %%
df_report.loc[(len(df.Category.unique())+1)*loop:(len(df.Category.unique())+1)*(loop+1)-2,colm]
# Out:
# 259        0.0
# 260        0.0
# 261        0.0
# 262        0.0
# 263        0.0
# 264        0.0
# 265        0.0
# 266        0.0
# 267        0.0
# 268        0.0
# 269        0.0
# 270        0.0
# 271        0.0
# 272        0.0
# 273        0.0
# 274        0.0
# 275        0.0
# 276        0.0
# 277        0.0
# 278        0.0
# 279        0.0
# 280        0.0
# 281        0.0
# 282        0.0
# 283        0.0
# 284    29181.0
# 285        0.0
# 286        0.0
# 287        0.0
# 288        0.0
# 289        0.0
# 290        0.0
# 291        0.0
# 292        0.0
# 293        0.0
# 294        0.0
# Name: Total revenue, dtype: float64

# %%
2*(len(df['Category'].unique())+1)
# Out:
# 74

# %%
pd.set_option('display.max_rows', 60)

# %%
a=pd.DataFrame({
    'a':[1,2,3,4]
})

# %%
a.loc[:,'woot']=['mario','luigi','wario','waluigi']

# %%
a
# Out:
#    a     woot
# 0  1    mario
# 1  2    luigi
# 2  3    wario
# 3  4  waluigi

# %%
def df_style(val):
    return "font-weight: bold"
df_report.style.map(df_style, subset=3)
# Out:
# <style type="text/css">
# #T_ecd9b_row3_col0, #T_ecd9b_row3_col1, #T_ecd9b_row3_col2, #T_ecd9b_row3_col3, #T_ecd9b_row3_col4, #T_ecd9b_row3_col5, #T_ecd9b_row3_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_ecd9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecd9b_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_ecd9b_level0_col1" class="col_heading level0 col1" >January</th>
#       <th id="T_ecd9b_level0_col2" class="col_heading level0 col2" >Feburary</th>
#       <th id="T_ecd9b_level0_col3" class="col_heading level0 col3" >March</th>
#       <th id="T_ecd9b_level0_col4" class="col_heading level0 col4" >April</th>
#       <th id="T_ecd9b_level0_col5" class="col_heading level0 col5" >May</th>
#       <th id="T_ecd9b_level0_col6" class="col_heading level0 col6" >Total revenue months</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
df_report
# Out:
# <style type="text/css">
# #T_e65e6_row1_col0, #T_e65e6_row1_col1, #T_e65e6_row1_col2, #T_e65e6_row1_col3, #T_e65e6_row1_col4, #T_e65e6_row1_col5, #T_e65e6_row1_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_e65e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e65e6_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_e65e6_level0_col1" class="col_heading level0 col1" >January</th>
#       <th id="T_e65e6_level0_col2" class="col_heading level0 col2" >Feburary</th>
#       <th id="T_e65e6_level0_col3" class="col_heading level0 col3" >March</th>
#       <th id="T_e65e6_level0_col4" class="col_heading level0 col4" >April</th>
#       <th id="T_e65e6_level0_col5" class="col_heading level0 col5" >May</th>
#       <th id="T_e65e6_level0_col6" class="col_heading level0 col6" >Total revenue months</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
